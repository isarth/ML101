# %%
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
from sklearn.cluster import KMeans

# %%
mean_1=[0,0]
cov_1=[[1,0],[0,1]]
mean_2=[2,2]
cov_2=[[0.8,0.2],[0.2,0.8]]

dist_1=np.random.multivariate_normal(mean_1,cov_1,200)
dist_2=np.random.multivariate_normal(mean_2,cov_2,200)


plt.scatter(dist_1[:,0],dist_1[:,1],color='red')
plt.scatter(dist_2[:,0],dist_2[:,1],color='green')

# %%
data=np.zeros((200,2))
data=dist_1+dist_2

# %%
data_std=np.std?

# %%
# Out:
# ()

# %%
data_std=std

# %%
plt.scatter(data[:,0],data[:,1])
plt.show()

# %%
def dist(p1,p2):
    return np.sqrt(((p1-p2)**2).sum())

# %%
k=3
dim=data.shape[1]
centers=np.random.random((k,dim))
print centers.shape
cluster={}
for kx in range(k):
    cluster[kx]={
        'center':centers[kx,:],
        'points':[]
    }
print cluster
# Out:
# (3, 2)
# {0: {'points': [], 'center': array([ 0.96682945,  0.72194679])}, 1: {'points': [], 'center': array([ 0.42701029,  0.4172545 ])}, 2: {'points': [], 'center': array([ 0.32937129,  0.31026082])}}

# %%
cluster[0]['points']
# Out:
# []

# %%
for px in range(data.shape[0]):
    distance_px=[]
    for kx in range(k):
        distance_px.append(dist(data[px,:],cluster[kx]['center']))
    distance_px=np.asarray((distance_px))
    c_id=distance_px.argmin()
    print c_id
    cluster[c_id]['points'].append(data[px, :])
    #print cluster
plt.figure(0)
cols = ['red', 'green', 'blue', 'yellow', 'pink']

for kx in range(k):
    pts = np.asarray(cluster[kx]['points'])
    plt.scatter(pts[:, 0], pts[:, 1], color=cols[kx])
    plt.scatter(cluster[kx]['center'][0], cluster[kx]['center'][1], color='black')
    c = cluster[kx]['center']
    cluster[kx]['center'] = pts.mean(axis=0)
    shifts[kx].append(dist(cluster[kx]['center'], c))
    cluster[kx]['points'] = []
plt.show()
# Out:
# 0
# {0: {'points': [array([ 1.36363108,  2.2044251 ])], 'center': array([ 0.96682945,  0.72194679])}, 1: {'points': [], 'center': array([ 0.42701029,  0.4172545 ])}, 2: {'points': [], 'center': array([ 0.32937129,  0.31026082])}}
# 0
# {0: {'points': [array([ 1.36363108,  2.2044251 ]), array([ 3.48908875,  3.62736774])], 'center': array([ 0.96682945,  0.72194679])}, 1: {'points': [], 'center': array([ 0.42701029,  0.4172545 ])}, 2: {'points': [], 'center': array([ 0.32937129,  0.31026082])}}
# 0
# {0: {'points': [array([ 1.36363108,  2.2044251 ]), array([ 3.48908875,  3.62736774]), array([ 1.58099228,  2.14505541])], 'center': array([ 0.96682945,  0.72194679])}, 1: {'points': [], 'center': array([ 0.42701029,  0.4172545 ])}, 2: {'points': [], 'center': array([ 0.32937129,  0.31026082])}}
# 0
# ...

# %%
f
